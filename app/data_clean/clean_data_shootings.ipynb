# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip3 install numpy
# !pip3 install pandas
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from csv import DictReader, reader
from datetime import date

# %%
#read Open_Streets_Locations.csv
raw_df = pd.read_csv('./../output/NYPD_Shooting_Data_Recent.csv')

# %%
raw_df
# Out:
#       OCCUR_DATE           BORO              LOCATION_DESC  \
# 0     07/01/2018       BROOKLYN                        NaN
# 1     07/01/2018         QUEENS                        NaN
# 2     07/02/2018         QUEENS  MULTI DWELL - PUBLIC HOUS
# 3     07/03/2018       BROOKLYN  MULTI DWELL - PUBLIC HOUS
# 4     07/03/2018       BROOKLYN    MULTI DWELL - APT BUILD
# ...          ...            ...                        ...
# 5438  12/31/2021  STATEN ISLAND                  PVT HOUSE
# 5439  12/31/2021       BROOKLYN  MULTI DWELL - PUBLIC HOUS
# 5440  12/31/2021       BROOKLYN                        NaN
# 5441  12/31/2021          BRONX  MULTI DWELL - PUBLIC HOUS
# 5442  12/31/2021      MANHATTAN  MULTI DWELL - PUBLIC HOUS
#
#       STATISTICAL_MURDER_FLAG   Latitude  Longitude
# 0                       False  40.680334 -73.938425
# 1                       False  40.682524 -73.790892
# 2                       False  40.754974 -73.946355
# ...

# %%
# !pip3 install uszipcode
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from uszipcode import SearchEngine
search = SearchEngine()

# %%
for i in range(len(raw_df)):
    result = search.by_coordinates(raw_df.loc[i, 'Latitude'], raw_df.loc[i, 'Longitude'], radius=3)
    raw_df.loc[i, 'zipcode'] = result[0].zipcode

# %%
raw_df
# Out:
#       OCCUR_DATE           BORO              LOCATION_DESC  \
# 0     07/01/2018       BROOKLYN                        NaN
# 1     07/01/2018         QUEENS                        NaN
# 2     07/02/2018         QUEENS  MULTI DWELL - PUBLIC HOUS
# 3     07/03/2018       BROOKLYN  MULTI DWELL - PUBLIC HOUS
# 4     07/03/2018       BROOKLYN    MULTI DWELL - APT BUILD
# ...          ...            ...                        ...
# 5438  12/31/2021  STATEN ISLAND                  PVT HOUSE
# 5439  12/31/2021       BROOKLYN  MULTI DWELL - PUBLIC HOUS
# 5440  12/31/2021       BROOKLYN                        NaN
# 5441  12/31/2021          BRONX  MULTI DWELL - PUBLIC HOUS
# 5442  12/31/2021      MANHATTAN  MULTI DWELL - PUBLIC HOUS
#
#       STATISTICAL_MURDER_FLAG   Latitude  Longitude zipcode
# 0                       False  40.680334 -73.938425   11216
# 1                       False  40.682524 -73.790892   11436
# 2                       False  40.754974 -73.946355   10044
# ...

# %%
raw_df.to_csv('../../output/Processed-shootings-zipcodes.csv', index=False)
